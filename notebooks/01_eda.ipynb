# %%
# Imports and data loading
import pandas as pd
import sys
sys.path.append('../worldcup_pkg')
from worldcup_pkg import load_worldcup_data, load_international_data
from worldcup_pkg.features import build_match_features

wc = load_worldcup_data()
intl = load_international_data()
print(wc.head())

# %%
# Build features and EDA
features_df = build_match_features(wc, intl)
print(features_df.describe())
features_df['home_win'].hist()
